# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-06-24 16:30:45--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   246MB/s    in 0.3s
#
# 2022-06-24 16:30:48 (246 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 7417   1712.06695v1  Estimators computed from adaptively collected ...  stat
# 22932  1711.02283v2  This paper presents a novel two-step approach ...  stat
# 35299  cs/0310005v1  We apply the optimization algorithm Adaptive S...    cs
# 6072   1606.08561v2  We develop a classification algorithm for esti...  stat
# 6932   1707.07576v1  In this work we present the novel ASTRID metho...  stat
# ...             ...                                                ...   ...
# 7672   1802.07295v1  As the prevalence and everyday use of machine ...  stat
# 32326   1408.6617v1  In this paper, we study the generalization per...    cs
# 27191  1702.07191v2  As the intermediate level task connecting imag...    cs
# 21167  1709.05067v1  Deep reinforcement learning is revolutionizing...    cs
# 3947   cs/0601129v1  This paper presents a review of instantaneousl...    cs
#
#                                                    title  year  \
# 7417       Accurate Inference for Adaptive Linear Models  2017
# 22932  Large-Scale Optimal Transport and Mapping Esti...  2017
# 35299  Using Artificial Intelligence for Model Selection  2003
# 6072   Estimating the class prior and posterior from ...  2016
# 6932   Interpreting Classifiers through Attribute Int...  2017
# ...                                                  ...   ...
# 7672   Attack Strength vs. Detectability Dilemma in A...  2018
# 32326  Task-group Relatedness and Generalization Boun...  2014
# 27191  ViP-CNN: Visual Phrase Guided Convolutional Ne...  2017
# 21167  Deep Reinforcement Learning for Conversational AI  2017
# 3947             Instantaneously Trained Neural Networks  2006
#
#                                                 keywords
# 7417   [estimators, adaptively, collected, sequential...
# 22932  [fundamental, distribution, transport, distrib...
# 35299  [optimization, algorithm, simulated, annealing...
# 6072   [classification, algorithm, estimating, poster...
# 6932   [investigating, attribute, interactions, class...
# ...                                                  ...
# 7672   [prevalence, algorithms, algorithms, dramatica...
# 32326  [generalization, performance, regularized, fra...
# 27191  [intermediate, connecting, captioning, detecti...
# 21167  [reinforcement, revolutionizing, artificial, i...
# 3947   [instantaneously, classification, applications...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 7417     [estimators, adaptively, collected, sequential...
# 22932    [fundamental, distribution, transport, distrib...
# 35299    [optimization, algorithm, simulated, annealing...
# 6072     [classification, algorithm, estimating, poster...
# 6932     [investigating, attribute, interactions, class...
#                                ...
# 21213    [induction, assumption, inputoutput, underlyin...
# 22874    [fundamental, inferring, direction, univariate...
# 36441    [introduce, entailment, propositional, classic...
# 23493    [clustering, technique, feedforward, unsupervi...
# 22890    [understanding, fundamental, experience, succe...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8832 words.
# Out of those 4554 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="46aa4a3e-ce28-4a0c-b29e-9c93aa2db336" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("46aa4a3e-ce28-4a0c-b29e-9c93aa2db336")) {                    Plotly.newPlot(                        "46aa4a3e-ce28-4a0c-b29e-9c93aa2db336",                        [{"x":["empirical","autoregressive","regression","martingale","dependence","estimators","decorrelation","collection","adaptively","confidence","distributional","demonstrate","transforming","inference","sequential","intervals","information","asymptotically","procedure","propensity","estimator","different","knowledge","collected","estimation","previously","applications","generalization","theoretical","continuous","generative","empirically","distributions","projection","regularized","fundamental","distribution","underlying","stochastic","adaptation","stability","estimations","approximating","transport","parameterization","artificial","complicated","intelligence","analyzing","simulated","traditional","selecting","optimization","population","individual","annealing","particular","numerically","algorithm","selection","constitutes","positives","parametric","transforms","classification","algorithms","explicitly","performing","contaminated","unlabeled","effective","contributions","posterior","univariate","discriminative","practical","dimensional","important","development","typically","classifiers","estimating","nonparametric","attribute","investigate","associations","pharmacovigilance","nucleotide","revealing","interactions","attributes","interpreting","bioinformatics","partitioning","investigating","factorisation","generating","polymorphisms","predictions","interpretable","framework","complexity","interested","performance","interestingly","generally","probability","logarithmic","distinguishable","principles","illustrative","efficiently","organizes","nonincremental","solutions","continually","experience","optimally","incremental","searching","experiments","involving","essentially","universal","characterized","variables","presenting","recalling","databases","improvement","opportunities","clustering","probabilistic","essential","geometrical","primitives","simulation","efficiency","alternative","controllable","parameters","integrating","properties","regarding","generation","constructive","favorable","dynamically","assurance","difficulty","adjustment","criterion","controllability","generated","procedural","motivated","adaptable","generates","automatically","extensive","immediately","subsequently","hypothetical","parameter","disciplines","extracting","comparatively","investment","phenomenological","sequences","predicted","effortlessly","resistance","practitioners","extracted","manipulate","monitoring","scientific","characteristics","practitioner","capability","constrained","described","assessment","application","corresponding","concatenating","correlation","optimizing","successfully","iterative","synthetic","illumination","conditions","canonical","expressions","experimental","occlusions","extraction","robustness"],"y":[176,5,109,0,17,10,1,74,28,33,17,549,9,215,72,12,676,11,121,2,25,707,365,75,208,117,424,99,155,110,119,72,96,46,43,83,205,123,135,70,30,4,18,7,10,142,27,87,66,60,173,38,331,60,120,12,284,9,802,175,9,6,37,16,500,614,81,89,5,33,255,47,54,3,104,130,192,374,131,101,114,70,20,37,132,15,2,1,5,66,59,10,10,24,15,2,104,0,81,25,580,246,40,867,12,75,175,14,2,39,9,146,3,2,169,6,43,20,29,24,580,57,24,34,30,142,16,1,55,139,20,157,164,75,15,11,70,154,106,4,259,36,200,44,159,10,10,36,3,51,13,46,2,167,6,75,7,52,170,166,7,20,4,123,11,57,4,7,2,86,42,3,2,14,126,8,45,41,89,3,51,72,60,33,262,140,3,81,44,86,88,123,33,150,20,49,406,15,133,104],"type":"bar"},{"x":["empirical","autoregressive","regression","martingale ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4554,), (4554, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8091666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Generative</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Deconvolutional</span> <span style=''>Image</span> <span style=''>Model</span> <br/><br/><span style=''>A</span> <span style=''>deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generative</span> <span style=''>model</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>developed</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.34971644612476366);'>representation</span> <span style=''>and</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>images</span> <span style=''>based</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>hierarchical</span> <span style='background-color:rgba(0, 255, 0, 0.6052631578947367);'>convolutional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dictionary</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style='background-color:rgba(255, 0, 0, 0.309462915601023);'>Stochastic</span> <span style=''>em</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unpooling</span> <span style=''>is</span> <span style=''>employed</span> <span style=''>to</span> <span style=''>link</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consecutive</span> <span style=''>layers</span> <span style=''>in</span> <span style=''>the</span> <span style=''>model</span> <span style=''>yielding</span> <span style=''>top</span> <span style=''>down</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.6649214659685864);'>generation</span> <span style=''>A</span> <span style=''>Bayesian</span> <span style=''>support</span> <span style=''>vector</span> <span style=''>machine</span> <span style=''>is</span> <span style=''>linked</span> <span style=''>to</span> <span style=''>the</span> <span style=''>top</span> <span style=''>layer</span> <span style=''>features</span> <span style=''>yielding</span> <span style=''>max</span> <span style=''>margin</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discrimination</span> <span style=''>Deep</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>deconvolutional</span> <span style='background-color:rgba(255, 0, 0, 0.3030794165316045);'>inference</span> <span style=''>is</span> <span style=''>employed</span> <span style=''>when</span> <span style=''>testing</span> <span style=''>to</span> <span style=''>infer</span> <span style=''>the</span> <span style=''>latent</span> <span style=''>features</span> <span style=''>and</span> <span style=''>the</span> <span style=''>top</span> <span style=''>layer</span> <span style=''>features</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.39215686274509803);'>connected</span> <span style=''>with</span> <span style=''>the</span> <span style=''>max</span> <span style=''>margin</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifier</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discrimination</span> <span style=''>tasks</span> <span style=''>The</span> <span style=''>model</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style=''>trained</span> <span style=''>using</span> <span style=''>a</span> <span style=''>Monte</span> <span style=''>Carlo</span> <span style='background-color:rgba(255, 0, 0, 0.4047619047619047);'>expectation</span> <span style='background-color:rgba(255, 0, 0, 0.35064935064935054);'>maximization</span> <span style=''>(MCEM)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implementation</span> <span style=''>on</span> <sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Generalized</span> <span style=''>Additive</span> <span style=''>Model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selection</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>GAMSEL</span> <span style=''>(Generalized</span> <span style=''>Additive</span> <span style=''>Model</span> <span style=''>Selection)</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>penalized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style=''>approach</span> <span style=''>for</span> <span style=''>fitting</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalized</span> <span style=''>additive</span> <span style=''>models</span> <span style=''>in</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>Our</span> <span style=''>method</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpolates</span> <span style=''>between</span> <span style=''>null</span> <span style=''>linear</span> <span style=''>and</span> <span style=''>additive</span> <span style=''>models</span> <span style=''>by</span> <span style=''>allowing</span> <span style=''>the</span> <span style=''>effect</span> <span style=''>of</span> <span style=''>each</span> <span style=''>variable</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimated</span> <span style=''>as</span> <span style=''>being</span> <span style=''>either</span> <span style=''>zero</span> <span style=''>linear</span> <span style=''>or</span> <span style=''>a</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complexity</span> <span style=''>curve</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>determined</span> <span style=''>by</span> <span style=''>the</span> <span style=''>data</span> <span style=''>We</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>blockwise</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coordinate</span> <span style=''>descent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimizing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>penalized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objective</span> <span style=''>over</span> <span style=''>a</span> <span style=''>dense</span> <span style=''>grid</span> <span style=''>of</span> <span style=''>the</span> <span style=''>tuning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>producing</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>path</span> <span style=''>of</span> <span style=''>additive</span> <span style=''>models</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>our</span> <span style=''>method</span> <span style=''>on</span> <span style=''>both</span> <span style=''>real</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulated</span> <span style=''>data</span> <span style=''>examples</span> <span style=''>and</span> <span style=''>compare</span> <span style=''>it</span> <span style=''>with</span> <span style=''>existing< ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Dantzig</span> <span style=''>Selector</span> <span style=''>Approach</span> <span style=''>to</span> <span style=''>Temporal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Difference</span> <span style=''>Learning</span> <br/><br/><span style=''>LSTD</span> <span style=''>is</span> <span style=''>a</span> <span style=''>popular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>value</span> <span style=''>function</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximation</span> <span style=''>Whenever</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>features</span> <span style=''>is</span> <span style=''>larger</span> <span style=''>than</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>samples</span> <span style=''>it</span> <span style=''>must</span> <span style=''>be</span> <span style=''>paired</span> <span style=''>with</span> <span style=''>some</span> <span style=''>form</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.30327868852459017);'>regularization</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>L1</span> <span style='background-color:rgba(255, 0, 0, 0.30327868852459017);'>regularization</span> <span style=''>methods</span> <span style=''>tend</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>feature</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>promoting</span> <span style=''>sparsity</span> <span style=''>and</span> <span style=''>thus</span> <span style=''>are</span> <span style=''>well</span> <span style=''>suited</span> <span style=''>for</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3298429319371728);'>dimensional</span> <span style=''>problems</span> <span style=''>However</span> <span style=''>since</span> <span style=''>LSTD</span> <span style=''>is</span> <span style=''>not</span> <span style=''>a</span> <span style=''>simple</span> <span style='background-color:rgba(255, 0, 0, 0.5341880341880342);'>regression</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>but</span> <span style=''>it</span> <span style=''>solves</span> <span style=''>a</span> <span style=''>fixed</span> <span style=''>point</span> <span style=''>problem</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.44444444444444453);'>integration</span> <span style=''>with</span> <span style=''>L1</span> <span style='background-color:rgba(255, 0, 0, 0.30327868852459017);'>regularization</span> <span style=''>is</span> <span style=''>not</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>straightforward</span> <span style=''>and</span> <span style=''>might</span> <span style=''>come</span> <span style=''>with</span> <span style=''>some</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>drawbacks</span> <span style=''>(eg</span> <span style=''>the</span> <span style=''>P</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>assumption</span> <span style=''>for</span> <span style=''>LASSO</span> <span style=''>TD)</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>novel</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>obtained</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3090909090909091);'>integrating</span> <span style=''>LSTD</span> <span style=''>with</span> <span style=''> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style=''>Adaptive</span> <span style=''>Newton</span> <span style=''>Method</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Explorative</span> <span style=''>Learning</span> <br/><br/><span style=''>We</span> <span style=''>present</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style=''>Adaptive</span> <span style=''>Newton</span> <span style=''>(VAN)</span> <span style=''>method</span> <span style=''>which</span> <span style=''>is</span> <span style=''>a</span> <span style=''>black</span> <span style=''>box</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>method</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>especially</span> <span style=''>suitable</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explorative</span> <span style=''>learning</span> <span style=''>tasks</span> <span style=''>such</span> <span style=''>as</span> <span style=''>active</span> <span style=''>learning</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reinforcement</span> <span style=''>learning</span> <span style=''>Similar</span> <span style=''>to</span> <span style=''>Bayesian</span> <span style=''>methods</span> <span style=''>VAN</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimates</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exploration</span> <span style=''>but</span> <span style=''>requires</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computations</span> <span style=''>that</span> <span style=''>are</span> <span style=''>similar</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>methods</span> <span style=''>Our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>contribution</span> <span style=''>reveals</span> <span style=''>that</span> <span style=''>VAN</span> <span style=''>is</span> <span style=''>a</span> <span style=''>second</span> <span style=''>order</span> <span style=''>method</span> <span style=''>that</span> <span style=''>unifies</span> <span style=''>existing</span> <span style=''>methods</span> <span style=''>in</span> <span style=''>distinct</span> <span style=''>fields</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>evolution</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>strategies</span> <span style=''>Our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimental</span> <span style=''>results</span> <span style=''>show</span> <span style=''>that</span> <span style=''>VAN</span> <span style=''>performs</span> <span style=''>well</span> <span style=''>on</span> <span style=''>a</span> <span style=''>wide</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>tasks</span> <span style=''>This</span> <span style=''>work</span> <span style=''>presents</span> <span style=''>a</span> <span style=''>general</span> <span style=''>purpose</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explorative</span> <sp ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.09832561453509084)
# 	information (0.2408265051656573)
# 	architecture (0.08371927324545779)
# 	knowledge (0.1300320627003919)
# 	segmentation (0.07623797648735305)
# 	experimental (0.14463840399002495)
# 	different (0.2518703241895262)
# 	detection (0.12290701816886355)
# 	recognition (0.12290701816886355)
# 	convolutional (0.13038831492696829)
#
# Some Statistics words are:
# 	distributions (0.12042147516307075)
# 	algorithm (0.3878575012543904)
# 	variables (0.1545408931259408)
# 	theoretical (0.16106372303060712)
# 	estimation (0.1816357250376317)
# 	statistical (0.16407425990968388)
# 	distribution (0.19066733567486202)
# 	dimensional (0.19116909182137481)
# 	inference (0.2017059708981435)
# 	regression (0.18013045659809332)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="37b00b26-043c-4bc7-84e2-df98fc64660d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("37b00b26-043c-4bc7-84e2-df98fc64660d")) {                    Plotly.newPlot(                        "37b00b26-043c-4bc7-84e2-df98fc64660d",                        [{"x":["empirical","autoregressive","regression","martingale","dependence","estimators","decorrelation","collection","adaptively","confidence","distributional","demonstrate","transforming","inference","sequential","intervals","information","asymptotically","procedure","propensity","estimator","different","knowledge","collected","estimation","previously","applications","generalization","theoretical","continuous","generative","empirically","distributions","projection","regularized","fundamental","distribution","underlying","stochastic","adaptation","stability","estimations","approximating","transport","parameterization","artificial","complicated","intelligence","analyzing","simulated","traditional","selecting","optimization","population","individual","annealing","particular","numerically","algorithm","selection","constitutes","positives","parametric","transforms","classification","algorithms","explicitly","performing","contaminated","unlabeled","effective","contributions","posterior","univariate","discriminative","practical","dimensional","important","development","typically","classifiers","estimating","nonparametric","attribute","investigate","associations","pharmacovigilance","nucleotide","revealing","interactions","attributes","interpreting","bioinformatics","partitioning","investigating","factorisation","generating","polymorphisms","predictions","interpretable","framework","complexity","interested","performance","interestingly","generally","probability","logarithmic","distinguishable","principles","illustrative","efficiently","organizes","nonincremental","solutions","continually","experience","optimally","incremental","searching","experiments","involving","essentially","universal","characterized","variables","presenting","recalling","databases","improvement","opportunities","clustering","probabilistic","essential","geometrical","primitives","simulation","efficiency","alternative","controllable","parameters","integrating","properties","regarding","generation","constructive","favorable","dynamically","assurance","difficulty","adjustment","criterion","controllability","generated","procedural","motivated","adaptable","generates","automatically","extensive","immediately","subsequently","hypothetical","parameter","disciplines","extracting","comparatively","investment","phenomenological","sequences","predicted","effortlessly","resistance","practitioners","extracted","manipulate","monitoring","scientific","characteristics","practitioner","capability","constrained","described","assessment","application","corresponding","concatenating","correlation","optimizing","successfully","iterative","synthetic","illumination","conditions","canonical","expressions","experimental","occlusions","extraction","robustness","interpretation","recognition","stagewise","neurosciences","outperforms","approaches","discretely","initialization","effectively","comparable","unreliable","regularizing","problematic","crowdsourcing","participants","techniques","dependent","consistency","instantiation","predictive","potential","aggregation","comprising","specifically","preferences","coarsening","projecting","incomplete","assumption","alternatives","statistical","observations","quantization","accordingly","exploiting","technique","computations","depending","localization","resources","formulated","terminate","retrieval","significantly","effectiveness","measuring","computational","appearance","introduce","preserving","modifying","ev ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	martingale
# 	polymorphisms
# 	stagewise
# 	interrelated
# 	precludes
# 	laplacians
# 	determinant
# 	confounder
# 	isometrically
# 	archetypal
# 	unregularized
# 	comorbidity
# 	oscillates
# 	hemoglobin
# 	triggering
# 	nonparametrically
# 	statistician
# 	coalescent
# 	overconfident
# 	semiparametric
# Some words which never appear in Statistics papers:
# 	organizes
# 	nonincremental
# 	continually
# 	assurance
# 	controllability
# 	phenomenological
# 	resistance
# 	concatenating
# 	illumination
# 	occlusions
# 	rotationally
# 	microscope
# 	authorities
# 	organisational
# 	configuring
# 	annotating
# 	grounding
# 	organisms
# 	displaced
# 	displacement

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.065228052967141e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7575
